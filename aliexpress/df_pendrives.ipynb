# %%
import pandas as pd

# %%
df = pd.read_csv('pendrives_2023-04-30_21-02-18.csv')
df
# Out:
#                                         product_title    price
# 0   Kootion u209 32gb 64gb 128gb usb tipo-c flash ...   R$8.09  \
# 1   O flash de suer mini usb conduz a movimentação...   R$4.99
# 2   Pen drive usb de alta velocidade 2.0 mini flas...   R$5.79
# 3   64gb prata por atacado memória vara 32gb capac...   R$4.99
# 4   Usb flash drive 3.0 de alta velocidade de 128g...  R$21.39
# ..                                                ...      ...
# 95  Controlador de jogo modelo usb flash drive 64g...  R$23.96
# 96  Para iphone relâmpago ios otg flash drive memo...   R$9.05
# 97  Push and Pull portátil USB Flash Drives 32G 64...  R$10.67
# 98  Movimentação de alta velocidade da pena de otg...  R$12.34
# 99  U & H Pendrive USB Leite Chá Pendrive Pen driv...  R$28.57
#
#           quantity_sold  rating
# 0    1,000+  vendido(s)     4.7
# 1       181  vendido(s)     4.4
# 2      600+  vendido(s)     4.5
# 3        28  vendido(s)     5.0
# 4   10,000+  vendido(s)     4.6
# ...

# %%
df.isnull()
# Out:
#     product_title  price  quantity_sold  rating
# 0           False  False          False   False
# 1           False  False          False   False
# 2           False  False          False   False
# 3           False  False          False   False
# 4           False  False          False   False
# ..            ...    ...            ...     ...
# 95          False  False          False    True
# 96          False  False          False   False
# 97          False  False          False   False
# 98          False  False          False   False
# 99          False  False          False   False
#
# [100 rows x 4 columns]

# %%
df = df.dropna()

# %%
df.loc[:, 'quantity_sold'] = df['quantity_sold'].str.replace('vendido(s)', '')

# %%
df
# Out:
#                                         product_title    price quantity_sold
# 0   Kootion u209 32gb 64gb 128gb usb tipo-c flash ...   R$8.09      1,000+    \
# 1   O flash de suer mini usb conduz a movimentação...   R$4.99         181
# 2   Pen drive usb de alta velocidade 2.0 mini flas...   R$5.79        600+
# 3   64gb prata por atacado memória vara 32gb capac...   R$4.99          28
# 4   Usb flash drive 3.0 de alta velocidade de 128g...  R$21.39     10,000+
# ..                                                ...      ...           ...
# 94  Metal pen drive gb 8 4gb gb pendrive usb flash...  R$13.02           9
# 96  Para iphone relâmpago ios otg flash drive memo...   R$9.05      1,000+
# 97  Push and Pull portátil USB Flash Drives 32G 64...  R$10.67         282
# 98  Movimentação de alta velocidade da pena de otg...  R$12.34          46
# 99  U & H Pendrive USB Leite Chá Pendrive Pen driv...  R$28.57          29
#
#     rating
# 0      4.7
# 1      4.4
# 2      4.5
# 3      5.0
# ...

# %%
df.to_csv('pendrives.csv', index=False)
